# %%
from YouTuBeDNN_ranking import RankingDNN
from tensorflow import keras

model = RankingDNN().build_model()
# Out:
# WARNING:tensorflow:From c:\Users\yuanshuai\AppData\Local\anaconda3\envs\tensorflow2\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\yuanshuai\AppData\Local\anaconda3\envs\tensorflow2\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
#现在绘制模型：
keras.utils.plot_model(model, "multi_input_and_output_model.png", show_shapes=True)
